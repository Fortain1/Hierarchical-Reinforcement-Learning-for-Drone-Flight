# %%
import matplotlib.pyplot as plt
import numpy as np

theta = np.linspace(0, 2 * np.pi, 100)
y = 10*np.cos(theta)
z = 10*np.sin(theta)
phi = np.pi/9
def xy(r,phi):
  return r*np.cos(phi), r*np.sin(phi)

ax = plt.figure().add_subplot(projection='3d')
phis=np.arange(0,6.28,0.01)
r =0.25
ax.plot(*xy(r,phis), zs=1, zdir='z', c="red")

#ax.plot(x, x, zs=1, zdir='z', label='curve in (x,y)')
#ax.plot(x, y, m)
ax.plot(np.full(100, 0), np.full(100, 0), zs=np.linspace(0, 1, 100), label='curve in (x,y)', c="black")
ax.plot(np.linspace(0, 1, 100), np.full(100, 0), zs=np.full(100, 1), label='curve in (x,y)', c="black")
ax.plot(np.linspace(0, 0, 100), np.linspace(0, -1, 100), zs=np.full(100, 1), label='curve in (x,y)', c="red")
r =0.4
a = np.append(np.linspace(0, r, 157), np.linspace(r, 0, 157))
a = np.append(a, np.linspace(0, -r, 157))
a = np.append(a, np.linspace(-r,0, 157))

y, z = xy(r,phis)

ax.plot(np.full(628,0), ys=y+1, zs=z ,zdir='x', label='curve in (x,y)', c="blue")
ax.plot(np.linspace(0, 1, 100), np.linspace(0, -1, 100), zs=np.linspace(1, 0.3, 100), label='curve in (x,y)', c="blue")

#ax.plot(y, y, x, c="black")
ax.scatter(0, 0, 1, c="black")
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(0, 2)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

theta = np.linspace(0, 2 * np.pi, 100)
y = 10*np.cos(theta)
z = 10*np.sin(theta)
phi = np.pi/9
def xy(r,phi):
  return r*np.cos(phi), r*np.sin(phi)

ax = plt.figure().add_subplot(projection='3d')
phis=np.arange(0,6.28,0.01)
r =0.25
ax.plot(*xy(r,phis), zs=1, zdir='z', c="red")

#ax.plot(x, x, zs=1, zdir='z', label='curve in (x,y)')
#ax.plot(x, y, m)
ax.plot(np.full(100, 0), np.full(100, 0), zs=np.linspace(0, 1, 100), label='curve in (x,y)', c="black")
ax.plot(np.linspace(0, 1, 100), np.full(100, 0), zs=np.full(100, 1), label='curve in (x,y)', c="black")
ax.plot(np.linspace(0, 0, 100), np.linspace(0, -1, 100), zs=np.full(100, 1), label='curve in (x,y)', c="red")
r =0.4

#ax.plot(y, y, x, c="black")
ax.scatter(0, 0, 1, c="black")
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(0, 2)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

phi = np.pi/9
def xy(r,phi):
  return r*np.cos(phi), r*np.sin(phi)

ax = plt.figure().add_subplot(projection='3d')
phis=np.arange(0,6.28,0.01)
r =0.25
# ax.plot(*xy(r,phis), zs=1, zdir='z', c="red")

ax.plot(np.full(100, 0), np.full(100, 0), zs=np.linspace(0, 1, 100), label='curve in (x,y)', c="black")
# ax.plot(np.linspace(0, 1, 100), np.full(100, 0), zs=np.full(100, 1), label='curve in (x,y)', c="black")
# ax.plot(np.linspace(0, 1, 100), np.linspace(0, -1, 100), zs=np.full(100, 1), label='curve in (x,y)', c="red")
theta = np.linspace(0, 2*np.pi, 100)
y = np.cos(theta)
z = np.sin(theta)
x = np.zeros_like(theta)  # X-coordinate for the circle center

# Plot circle
ax.plot(x, y, z+1, c="blue")

ax.plot(np.linspace(0, 0, 100), np.linspace(0, -1, 100), zs=np.linspace(1, 0.3, 100), label='curve in (x,y)', c="blue")

ax.scatter(0, -0.5555555555555556, 0.6111111111111112, c="green")
ax.scatter(0, 0, 1, c="black")
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(0, 2)
plt.show()
